# %% [markdown]
# # Python for Software Development
#
# Choose a specialization.
#
# ### 1. Backend Development
#
# Technologies:
#
# - FastAPI
#
# - Django
#
# - Flask
#
# ### 2. Concepts:
#
# - REST APIs
#
# - Authentication
#
# - JWT
#
# - Caching
#
# - Redis
#
# - Databases
#
# ### 3. Databases:
#
# - PostgreSQL
#
# - MySQL
#
# - MongoDB
#
# ### ORMs:
#
# - SQLAlchemy
#
# - Django ORM
